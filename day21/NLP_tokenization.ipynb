# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\vedas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

text= "today we are learning NLP"

tokens= word_tokenize(text)
print(tokens)
# Out:
# ['today', 'we', 'are', 'learning', 'NLP']

# %%
#Sentences Tokenization

from nltk.tokenize import sent_tokenize
text =""" artificial intelligence is transforming the world.
Natural Language Processing is a part of AI.
ChatGPT uses Transformer models"""

sentences = sent_tokenize(text)
print(sentences)
# Out:
# [' artificial intelligence is transforming the world.', 'Natural Language Processing is a part of AI.', 'ChatGPT uses Transformer models']

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('punk')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\vedas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Error loading punk: Package 'punk' not found in index
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vedas\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from ntlk.corpus import stopwords
from ntlk.tokenize import word_tokenize

text = "I am learning Natural Language Processing"
stop_words = set(stopwords.words("english"))
tokens = word_tokenize(text)
filtered = [word for word in tokens if word not in stop_words  ]
print(filtered)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from ntlk.corpus import stopwords
#       2 from ntlk.tokenize import word_tokenize
#       4 text = "I am learning Natural Language Processing"
#
# ModuleNotFoundError: No module named 'ntlk'
