# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
#create dataset
data = {
    "Height":[185,170,168,179,182,188,180,183,180,180,177],
    "Weight":[80,70,65,75,80,85,80,82,78,79,76]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     Height  Weight
# 0      185      80
# 1      170      70
# 2      168      65
# 3      179      75
# 4      182      80
# 5      188      85
# 6      180      80
# 7      183      82
# 8      180      78
# 9      180      79
# 10     177      76
